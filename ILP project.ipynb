# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'C:\Users\lenovo\Desktop\indian_liver_patient.csv')

# %%
data
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
data.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
data.shape
# Out:
# (583, 11)

# %%
data.value_counts('Gender')
# Out:
# Gender
# Male      441
# Female    142
# Name: count, dtype: int64

# %%
sns.barplot(x='Gender',y='Total_Bilirubin',data=data);
plt.show()

# %%
data.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %% [markdown]
#  ####  - How many patients have liver disease (labeled as 1) and how many do not (labeled as 2)? Is there a class imbalance?

# %%
data['Dataset'].value_counts(normalize=True)*100
# Out:
# Dataset
# 1    71.35506
# 2    28.64494
# Name: proportion, dtype: float64

# %% [markdown]
# ####  Which features (e.g., total bilirubin, albumin, ALT) are most strongly correlated with liver disease, and which ones are less significant?

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
sns.pairplot(data,x_vars=[ 'Age','Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase',
       'Alamine_Aminotransferase', 'Aspartate_Aminotransferase',
       'Total_Protiens', 'Albumin', 'Albumin_and_Globulin_Ratio'],
             y_vars=['Dataset'],kind='reg')
plt.show()

# %%
X=data.drop(['Dataset','Gender'],axis=1)
Y=data['Dataset']

# %%
corr_df=X.corr(method="pearson")
print(corr_df)
# Out:
#                                  Age  Total_Bilirubin  Direct_Bilirubin  \
# Age                         1.000000         0.011763          0.007529
# Total_Bilirubin             0.011763         1.000000          0.874618
# Direct_Bilirubin            0.007529         0.874618          1.000000
# Alkaline_Phosphotase        0.080425         0.206669          0.234939
# Alamine_Aminotransferase   -0.086883         0.214065          0.233894
# Aspartate_Aminotransferase -0.019910         0.237831          0.257544
# Total_Protiens             -0.187461        -0.008099         -0.000139
# Albumin                    -0.265924        -0.222250         -0.228531
# Albumin_and_Globulin_Ratio -0.216408        -0.206267         -0.200125
#
#                             Alkaline_Phosphotase  Alamine_Aminotransferase  \
# Age                                     0.080425                 -0.086883
# Total_Bilirubin                         0.206669                  0.214065
# ...

# %%
sns.heatmap(corr_df,vmax=1.0,vmin=-1.0,annot=True)
plt.show()

# %% [markdown]
# #### Q3 What is the range of Total Bilirubin values in the dataset?

# %%
data1=data.Total_Bilirubin.min() 
print(data1)
data2=data.Total_Bilirubin.max()
print(data2)
range=data1-data2
print(range)
# Out:
# 0.4
# 75.0
# -74.6

# %% [markdown]
# #### - What is the correlation between Total Bilirubin and liver disease?

# %%
sns.pairplot(data,x_vars=['Total_Bilirubin'],
             y_vars=['Dataset'],kind='reg')
plt.show()

# %% [markdown]
# ####   Distribution of Numberical Features

# %%
data.hist(bins=10,figsize=(15,15))
plt.show()

# %% [markdown]
# ####  outlier

# %%
sns.boxplot(data);
plt.xticks(rotation=90);

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
sns.boxplot(data.Aspartate_Aminotransferase);

# %%
print(data.Aspartate_Aminotransferase.sort_values(ascending=False).head(10))
print(data.Aspartate_Aminotransferase.shape)
# Out:
# 135    4929
# 117    2946
# 118    1600
# 207    1500
# 119    1050
# 199    1050
# 47      960
# 97      950
# 410     850
# 92      850
# Name: Aspartate_Aminotransferase, dtype: int64
# (583,)

# %% [markdown]
# ####  remove outliers

# %%
df=data[data.Aspartate_Aminotransferase<=2500]
df.shape
# Out:
# (581, 11)

# %% [markdown]
# null  values

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
df=data.dropna(how='any')
df.shape
# Out:
# (579, 11)

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
sns.boxplot(data.Alamine_Aminotransferase)
# Out:
# <Axes: ylabel='Alamine_Aminotransferase'>

# %%
data.Alamine_Aminotransferase.sort_values(ascending=False).head(10)
# Out:
# 117    2000
# 27     1680
# 47     1630
# 118    1350
# 135    1250
# 119    1250
# 207     950
# 25      875
# 26      875
# 199     790
# Name: Alamine_Aminotransferase, dtype: int64
